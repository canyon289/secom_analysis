# %% [markdown]
# # Initial Data Load
# Check if data loads easily, and check data cleaning steps are needed

# %%
import pandas as pd

# %% [markdown]
# ## Secom Features dataset
# Visual inspection indicates that the file is space delimited with no headers

# %%
secom_x = pd.read_csv("../data/secom.data", delimiter=" ", header=None)

# %%
secom_x
# Out:
#           0        1          2          3       4      5         6       7    \
# 0     3030.93  2564.00  2187.7333  1411.1265  1.3602  100.0   97.6133  0.1242
# 1     3095.78  2465.14  2230.4222  1463.6606  0.8294  100.0  102.3433  0.1247
# 2     2932.61  2559.94  2186.4111  1698.0172  1.5102  100.0   95.4878  0.1241
# 3     2988.72  2479.90  2199.0333   909.7926  1.3204  100.0  104.2367  0.1217
# 4     3032.24  2502.87  2233.3667  1326.5200  1.5334  100.0  100.3967  0.1235
# 5     2946.25  2432.84  2233.3667  1326.5200  1.5334  100.0  100.3967  0.1235
# 6     3030.27  2430.12  2230.4222  1463.6606  0.8294  100.0  102.3433  0.1247
# 7     3058.88  2690.15  2248.9000  1004.4692  0.7884  100.0  106.2400  0.1185
# 8     2967.68  2600.47  2248.9000  1004.4692  0.7884  100.0  106.2400  0.1185
# 9     3016.11  2428.37  2248.9000  1004.4692  0.7884  100.0  106.2400  0.1185
# 10    2994.05  2548.21  2195.1222  1046.1468  1.3204  100.0  103.3400  0.1223
# ...

# %%
# Inspect first row
secom_x.iloc[0,:]
# Out:
# 0      3030.9300
# 1      2564.0000
# 2      2187.7333
# 3      1411.1265
# 4         1.3602
# 5       100.0000
# 6        97.6133
# 7         0.1242
# 8         1.5005
# 9         0.0162
# 10       -0.0034
# 11        0.9455
# 12      202.4396
# 13        0.0000
# 14        7.9558
# 15      414.8710
# 16       10.0433
# 17        0.9680
# 18      192.3963
# 19       12.5190
# 20        1.4026
# 21    -5419.0000
# 22     2916.5000
# 23    -4043.7500
# 24      751.0000
# 25        0.8955
# 26        1.7730
# 27        3.0490
# 28       64.2333
# 29        2.0222
#          ...
# 560       0.1039
# 561      42.3877
# 562          NaN
# 563          NaN
# 564          NaN
# 565          NaN
# 566          NaN
# 567          NaN
# 568          NaN
# 569          NaN
# 570     533.8500
# 571       2.1113
# 572       8.9500
# 573       0.3157
# 574       3.0624
# 575       0.1026
# 576       1.6765
# 577      14.9509
# 578          NaN
# 579          NaN
# 580          NaN
# ...

# %%
# Ensure that loaded shape matches size on website (1567 rows x 591 columns)
# The extra column missing here is the time column in labels dataset
secom_x.shape
# Out:
# (1567, 590)

# %% [markdown]
# ## Secom Labels dataset
# Load labels dataset

# %%
secom_y = pd.read_csv("../data/secom_labels.data", delimiter=" ", header=None)

# %%
secom_y
# Out:
#       0                    1
# 0    -1  19/07/2008 11:55:00
# 1    -1  19/07/2008 12:32:00
# 2     1  19/07/2008 13:17:00
# 3    -1  19/07/2008 14:43:00
# 4    -1  19/07/2008 15:22:00
# 5    -1  19/07/2008 17:53:00
# 6    -1  19/07/2008 19:44:00
# 7    -1  19/07/2008 19:45:00
# 8    -1  19/07/2008 20:24:00
# 9    -1  19/07/2008 21:35:00
# 10    1  19/07/2008 21:57:00
# 11    1  19/07/2008 22:52:00
# 12   -1  20/07/2008 03:35:00
# 13   -1  21/07/2008 08:21:00
# 14    1  21/07/2008 11:53:00
# 15   -1  22/07/2008 00:03:00
# 16   -1  22/07/2008 02:59:00
# 17   -1  22/07/2008 08:41:00
# 18   -1  22/07/2008 11:47:00
# 19   -1  22/07/2008 14:00:00
# 20   -1  22/07/2008 15:30:00
# 21   -1  23/07/2008 05:15:00
# 22   -1  23/07/2008 19:22:00
# 23    1  25/07/2008 15:23:00
# 24   -1  27/07/2008 04:18:00
# 25   -1  27/07/2008 09:37:00
# 26   -1  27/07/2008 11:10:00
# 27   -1  27/07/2008 15:46:00
# 28   -1  27/07/2008 16:06:00
# 29   -1  27/07/2008 16:49:00
# ...  ..                  ...
# ...

# %%
secom_y.dtypes
# Out:
# 0     int64
# 1    object
# dtype: object

# %%
# Coerce datetime column
timestamp = pd.to_datetime(secom_y[1])
timestamp.head()
# Out:
# 0   2008-07-19 11:55:00
# 1   2008-07-19 12:32:00
# 2   2008-07-19 13:17:00
# 3   2008-07-19 14:43:00
# 4   2008-07-19 15:22:00
# Name: 1, dtype: datetime64[ns]

# %% [markdown]
# ## Load JSON Dataset

# %%
secom_json = pd.read_json("../data/vendordata.json")
secom_json.head(40)
# Out:
#      adhs vendor            datetime mat vendor part vendor sil vendor  \
# 0            bbb 2008-07-19 11:55:00        ddd         aaa        ddd
# 1            aaa 2008-07-19 12:32:00        eee         ccc        ddd
# 10           aaa 2008-07-19 21:57:00        aaa         bbb        eee
# 100          bbb 2008-08-05 00:04:00        ddd         aaa        fff
# 1000         bbb 2008-09-22 00:12:00        bbb         ccc        iii
# 1001         aaa 2008-09-22 00:28:00        ccc         bbb        hhh
# 1002         aaa 2008-09-22 00:47:00        bbb         bbb        eee
# 1003         bbb 2008-09-22 01:43:00        fff         aaa        ccc
# 1004         aaa 2008-09-22 03:51:00        bbb         aaa        bbb
# 1005         aaa 2008-09-22 06:05:00        ccc         bbb        eee
# 1006         bbb 2008-09-22 07:12:00        bbb         bbb        ccc
# 1007         bbb 2008-09-22 10:43:00        ccc         ccc        eee
# ...

# %%
secom_json.shape
# Out:
# (1567, 6)

# %%
secom_json = secom_json.sort_index()

# %%
secom_json.head()
# Out:
#   adhs vendor            datetime mat vendor part vendor sil vendor sop vendor
# 0         bbb 2008-07-19 11:55:00        ddd         aaa        ddd        eee
# 1         aaa 2008-07-19 12:32:00        eee         ccc        ddd        aaa
# 2         aaa 2008-07-19 13:17:00        fff         aaa        eee        jjj
# 3         aaa 2008-07-19 14:43:00        ccc         ccc        hhh        eee
# 4         bbb 2008-07-19 15:22:00        ccc         bbb        aaa        iii

# %%
secom_json["datetime"].apply(lambda d: d.toordinal())
# Out:
# 0       733242
# 1       733242
# 2       733242
# 3       733242
# 4       733242
# 5       733242
# 6       733242
# 7       733242
# 8       733242
# 9       733242
# 10      733242
# 11      733242
# 12      733243
# 13      733244
# 14      733244
# 15      733245
# 16      733245
# 17      733245
# 18      733245
# 19      733245
# 20      733245
# 21      733246
# 22      733246
# 23      733248
# 24      733250
# 25      733250
# 26      733250
# 27      733250
# 28      733250
# 29      733250
#          ...
# 1537    733330
# 1538    733330
# 1539    733330
# 1540    733330
# 1541    733330
# 1542    733330
# 1543    733330
# 1544    733330
# 1545    733331
# 1546    733331
# 1547    733331
# 1548    733331
# 1549    733331
# 1550    733331
# 1551    733331
# 1552    733331
# 1553    733331
# 1554    733331
# 1555    733331
# 1556    733331
# 1557    733331
# 1558    733331
# 1559    733331
# 1560    733331
# 1561    733331
# 1562    733331
# 1563    733331
# ...
